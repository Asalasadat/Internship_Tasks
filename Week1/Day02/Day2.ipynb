# %% [markdown]
# task1: list of number and returns min, max and mean

# %%
import numpy as np# import numpy for numerical operations

# %%
numbers = [1, 2, 3, 4, 5] 
min = min(numbers) 
max = max(numbers) 
mean = np.mean(numbers)

# %% [markdown]
# task2: Rewrite a given for-loop that filters even numbers as a single list comprehension.

# %%
# for loop
even_numbers_for = [] 
for i in range(len(numbers)): 
    if numbers[i] % 2 == 0: 
        even_numbers_for.append(numbers[i])
# list comprehension
even_numbers_list_comp = [num for num in numbers if num % 2 == 0]

# %% [markdown]
# task2: Define a small class representing a data record with at least two attributes and one method.

# %%
class rectangle:
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width
